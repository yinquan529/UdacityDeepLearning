# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    a = 0
    b = 1
    X_min = 0
    X_max = 255
    
    return (a + ((x - X_min)*(b-a))/(X_max - X_min))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    from sklearn import preprocessing
    lb = preprocessing.LabelBinarizer()
    lb.fit(range(10))
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,(None, image_shape[0],image_shape[1],image_shape[2]),"x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,(None, n_classes),"y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,None,"keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    input_feature_map = x_tensor.get_shape()[3].value
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],input_feature_map,conv_num_outputs]))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_layer = tf.nn.conv2d(x_tensor,weight,strides = [1,conv_strides[0],conv_strides[1],1],padding='SAME')
    
    conv_layer = tf.nn.bias_add(conv_layer,bias)
    conv_layer = tf.nn.relu(conv_layer)
    
    conv_layer = tf.nn.max_pool(conv_layer,
                                ksize = [1,pool_ksize[0],pool_ksize[1],1], 
                                strides = [1, pool_strides[0],pool_strides[1],1],
                                padding='SAME')

    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    dim = np.prod(shape[1:])
    return tf.reshape(x_tensor,[-1,dim])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.truncated_normal([x_shape[1],num_outputs], mean=0.0, stddev=0.01))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    fc = tf.nn.bias_add(tf.matmul(x_tensor,weight),bias)
    
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.truncated_normal([x_shape[1],num_outputs]))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    return tf.nn.bias_add(tf.matmul(x_tensor,weight),bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_layer = conv2d_maxpool(x,
                                conv_num_outputs=150,
                                conv_ksize=[3,3],
                                conv_strides=[1,1],
                                pool_ksize=[3,3],
                                pool_strides=[1,1]
                               )
    conv_layer = conv2d_maxpool(x,
                            conv_num_outputs=150,
                            conv_ksize=[3,3],
                            conv_strides=[1,1],
                            pool_ksize=[3,3],
                            pool_strides=[1,1]
                           )
    
    
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #flatten(x_tensor)
    fl = flatten(conv_layer)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    # fully_conn(x_tensor, num_outputs)
    fc = fully_conn(fl,10)
    fc = fully_conn(fc,10)
    fc = tf.nn.dropout(fc,keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    # output(x_tensor, num_outputs)
    ot = output(fc,10)
    
    # TODO: return output
    return ot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch,y:label_batch,keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    lost = session.run(cost,feed_dict={x:feature_batch,y:label_batch,keep_prob:1.})
    valid_acc = session.run(accuracy,feed_dict={x:valid_features,y:valid_labels,keep_prob:1.})
    
    print('Lost: {:>10.4f} Validation Accuracy:{:6f}'.format(lost,valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 64
keep_probability = 0.75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Lost:     2.0073 Validation Accuracy:0.335600
# Epoch  2, CIFAR-10 Batch 1:  Lost:     1.7311 Validation Accuracy:0.356000
# Epoch  3, CIFAR-10 Batch 1:  Lost:     1.6304 Validation Accuracy:0.420400
# Epoch  4, CIFAR-10 Batch 1:  Lost:     1.4461 Validation Accuracy:0.463200
# Epoch  5, CIFAR-10 Batch 1:  Lost:     1.3289 Validation Accuracy:0.486200
# Epoch  6, CIFAR-10 Batch 1:  Lost:     1.2618 Validation Accuracy:0.497600
# Epoch  7, CIFAR-10 Batch 1:  Lost:     1.0707 Validation Accuracy:0.500000
# Epoch  8, CIFAR-10 Batch 1:  Lost:     0.9574 Validation Accuracy:0.513400
# Epoch  9, CIFAR-10 Batch 1:  Lost:     0.8773 Validation Accuracy:0.501400
# Epoch 10, CIFAR-10 Batch 1:  Lost:     0.7703 Validation Accuracy:0.553000
# Epoch 11, CIFAR-10 Batch 1:  Lost:     0.6274 Validation Accuracy:0.548000
# Epoch 12, CIFAR-10 Batch 1:  Lost:     0.5065 Validation Accuracy:0.556000
# Epoch 13, CIFAR-10 Batch 1:  Lost:     0.4319 Validation Accuracy:0.547200
# Epoch 14, CIFAR-10 Batch 1:  Lost:     0.4358 Validation Accuracy:0.559000
# Epoch 15, CIFAR-10 Batch 1:  Lost:     0.4056 Validation Accuracy:0.551600
# Epoch 16, CIFAR-10 Batch 1:  Lost:     0.2600 Validation Accuracy:0.555000
# Epoch 17, CIFAR-10 Batch 1:  Lost:     0.2925 Validation Accuracy:0.543600
# Epoch 18, CIFAR-10 Batch 1:  Lost:     0.2395 Validation Accuracy:0.550600
# Epoch 19, CIFAR-10 Batch 1:  Lost:     0.2810 Validation Accuracy:0.545400
# Epoch 20, CIFAR-10 Batch 1:  Lost:     0.2533 Validation Accuracy:0.514000
# Epoch 21, CIFAR-10 Batch 1:  Lost:     0.1973 Validation Accuracy:0.507200
# Epoch 22, CIFAR-10 Batch 1:  Lost:     0.1570 Validation Accuracy:0.500400
# Epoch 23, CIFAR-10 Batch 1:  Lost:     0.0827 Validation Accuracy:0.543400
# Epoch 24, CIFAR-10 Batch 1:  Lost:     0.1159 Validation Accuracy:0.523200
# Epoch 25, CIFAR-10 Batch 1:  Lost:     0.1800 Validation Accuracy:0.533000
# Epoch 26, CIFAR-10 Batch 1:  Lost:     0.0743 Validation Accuracy:0.551400
# Epoch 27, CIFAR-10 Batch 1:  Lost:     0.0937 Validation Accuracy:0.549800
# Epoch 28, CIFAR-10 Batch 1:  Lost:     0.1079 Validation Accuracy:0.543800
# Epoch 29, CIFAR-10 Batch 1:  Lost:     0.1087 Validation Accuracy:0.544000
# Epoch 30, CIFAR-10 Batch 1:  Lost:     0.0539 Validation Accuracy:0.543000
# Epoch 31, CIFAR-10 Batch 1:  Lost:     0.0704 Validation Accuracy:0.546800
# Epoch 32, CIFAR-10 Batch 1:  Lost:     0.0305 Validation Accuracy:0.537800
# Epoch 33, CIFAR-10 Batch 1:  Lost:     0.0249 Validation Accuracy:0.539800
# Epoch 34, CIFAR-10 Batch 1:  Lost:     0.0368 Validation Accuracy:0.547800
# Epoch 35, CIFAR-10 Batch 1:  Lost:     0.0460 Validation Accuracy:0.537600
# Epoch 36, CIFAR-10 Batch 1:  Lost:     0.0279 Validation Accuracy:0.552400
# Epoch 37, CIFAR-10 Batch 1:  Lost:     0.0266 Validation Accuracy:0.545600
# Epoch 38, CIFAR-10 Batch 1:  Lost:     0.0240 Validation Accuracy:0.527200
# Epoch 39, CIFAR-10 Batch 1:  Lost:     0.0493 Validation Accuracy:0.536000
# Epoch 40, CIFAR-10 Batch 1:  Lost:     0.0170 Validation Accuracy:0.550400
# Epoch 41, CIFAR-10 Batch 1:  Lost:     0.0115 Validation Accuracy:0.549400
# Epoch 42, CIFAR-10 Batch 1:  Lost:     0.0330 Validation Accuracy:0.536600
# Epoch 43, CIFAR-10 Batch 1:  Lost:     0.0196 Validation Accuracy:0.537400
# Epoch 44, CIFAR-10 Batch 1:  Lost:     0.0223 Validation Accuracy:0.539200
# Epoch 45, CIFAR-10 Batch 1:  Lost:     0.0177 Validation Accuracy:0.534600
# Epoch 46, CIFAR-10 Batch 1:  Lost:     0.0273 Validation Accuracy:0.523600
# Epoch 47, CIFAR-10 Batch 1:  Lost:     0.0104 Validation Accuracy:0.538600
# Epoch 48, CIFAR-10 Batch 1:  Lost:     0.0215 Validation Accuracy:0.539000
# Epoch 49, CIFAR-10 Batch 1:  Lost:     0.0081 Validation Accuracy:0.539600
# Epoch 50, CIFAR-10 Batch 1:  Lost:     0.0176 Validation Accuracy:0.535200
# Epoch 51, CIFAR-10 Batch 1:  Lost:     0.0077 Validation Accuracy:0.539600
# Epoch 52, CIFAR-10 Batch 1:  Lost:     0.0426 Validation Accuracy:0.519600
# Epoch 53, CIFAR-10 Batch 1:  Lost:     0.0091 Validation Accuracy:0.533000
# Epoch 54, CIFAR-10 Batch 1:  Lost:     0.0154 Validation Accuracy:0.522000
# Epoch 55, CIFAR-10 Batch 1:  Lost:     0.0042 Validation Accuracy:0.533200
# Epoch 56, CIFAR-10 Batch 1:  Lost:     0.0129 Validation Accuracy:0.523000
# Epoch 57, CIFAR-10 Batch 1:  Lost:     0.0055 Validation Accuracy:0.529400
# Epoch 58, CIFAR-10 Batch 1:  Lost:     0.0033 Validation Accuracy:0.528200
# Epoch 59, CIFAR-10 Batch 1:  Lost:     0.0083 Validation Accuracy:0.515400
# Epoch 60, CIFAR-10 Batch 1:  Lost:     0.0230 Validation Accuracy:0.531600
# Epoch 61, CIFAR-10 Batch 1:  Lost:     0.0047 Validation Accuracy:0.533400
# Epoch 62, CIFAR-10 Batch 1:  Lost:     0.0040 Validation Accuracy:0.533800
# Epoch 63, CIFAR-10 Batch 1:  Lost:     0.0035 Validation Accuracy:0.524200
# Epoch 64, CIFAR-10 Batch 1:  Lost:     0.0036 Validation Accuracy:0.532000
# Epoch 65, CIFAR-10 Batch 1:  Lost:     0.0045 Validation Accuracy:0.521600
# Epoch 66, CIFAR-10 Batch 1:  Lost:     0.0412 Validation Accuracy:0.485600
# Epoch 67, CIFAR-10 Batch 1:  Lost:     0.0082 Validation Accuracy:0.525200
# Epoch 68, CIFAR-10 Batch 1:  Lost:     0.0095 Validation Accuracy:0.533400
# Epoch 69, CIFAR-10 Batch 1:  Lost:     0.0022 Validation Accuracy:0.538000
# Epoch 70, CIFAR-10 Batch 1:  Lost:     0.0016 Validation Accuracy:0.541400
# Epoch 71, CIFAR-10 Batch 1:  Lost:     0.0097 Validation Accuracy:0.529800
# Epoch 72, CIFAR-10 Batch 1:  Lost:     0.0037 Validation Accuracy:0.540600
# Epoch 73, CIFAR-10 Batch 1:  Lost:     0.0033 Validation Accuracy:0.516600
# Epoch 74, CIFAR-10 Batch 1:  Lost:     0.0053 Validation Accuracy:0.518200
# Epoch 75, CIFAR-10 Batch 1:  Lost:     0.0018 Validation Accuracy:0.536800
# Epoch 76, CIFAR-10 Batch 1:  Lost:     0.0017 Validation Accuracy:0.539200
# Epoch 77, CIFAR-10 Batch 1:  Lost:     0.0034 Validation Accuracy:0.526400
# Epoch 78, CIFAR-10 Batch 1:  Lost:     0.0017 Validation Accuracy:0.535200
# Epoch 79, CIFAR-10 Batch 1:  Lost:     0.0052 Validation Accuracy:0.534600
# Epoch 80, CIFAR-10 Batch 1:  Lost:     0.0013 Validation Accuracy:0.550000
# Epoch 81, CIFAR-10 Batch 1:  Lost:     0.0015 Validation Accuracy:0.541600
# Epoch 82, CIFAR-10 Batch 1:  Lost:     0.0050 Validation Accuracy:0.549200
# Epoch 83, CIFAR-10 Batch 1:  Lost:     0.0038 Validation Accuracy:0.533600
# Epoch 84, CIFAR-10 Batch 1:  Lost:     0.0017 Validation Accuracy:0.529200
# Epoch 85, CIFAR-10 Batch 1:  Lost:     0.0038 Validation Accuracy:0.529200
# Epoch 86, CIFAR-10 Batch 1:  Lost:     0.0096 Validation Accuracy:0.522400
# Epoch 87, CIFAR-10 Batch 1:  Lost:     0.0018 Validation Accuracy:0.534000
# Epoch 88, CIFAR-10 Batch 1:  Lost:     0.0005 Validation Accuracy:0.526600
# Epoch 89, CIFAR-10 Batch 1:  Lost:     0.0061 Validation Accuracy:0.534800
# Epoch 90, CIFAR-10 Batch 1:  Lost:     0.0015 Validation Accuracy:0.542800
# Epoch 91, CIFAR-10 Batch 1:  Lost:     0.0006 Validation Accuracy:0.528600
# Epoch 92, CIFAR-10 Batch 1:  Lost:     0.0028 Validation Accuracy:0.542600
# Epoch 93, CIFAR-10 Batch 1:  Lost:     0.0030 Validation Accuracy:0.530200
# Epoch 94, CIFAR-10 Batch 1:  Lost:     0.0005 Validation Accuracy:0.531600
# Epoch 95, CIFAR-10 Batch 1:  Lost:     0.0035 Validation Accuracy:0.533200
# Epoch 96, CIFAR-10 Batch 1:  Lost:     0.0055 Validation Accuracy:0.532400
# Epoch 97, CIFAR-10 Batch 1:  Lost:     0.0005 Validation Accuracy:0.527600
# Epoch 98, CIFAR-10 Batch 1:  Lost:     0.0025 Validation Accuracy:0.535200
# Epoch 99, CIFAR-10 Batch 1:  Lost:     0.0006 Validation Accuracy:0.527000
# Epoch 100, CIFAR-10 Batch 1:  Lost:     0.0011 Validation Accuracy:0.536200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Lost:     1.9776 Validation Accuracy:0.418200
# Epoch  1, CIFAR-10 Batch 2:  Lost:     1.5010 Validation Accuracy:0.414000
# Epoch  1, CIFAR-10 Batch 3:  Lost:     1.2715 Validation Accuracy:0.478400
# Epoch  1, CIFAR-10 Batch 4:  Lost:     1.4377 Validation Accuracy:0.497200
# Epoch  1, CIFAR-10 Batch 5:  Lost:     1.4065 Validation Accuracy:0.509400
# Epoch  2, CIFAR-10 Batch 1:  Lost:     1.3805 Validation Accuracy:0.488800
# Epoch  2, CIFAR-10 Batch 2:  Lost:     1.2083 Validation Accuracy:0.533200
# Epoch  2, CIFAR-10 Batch 3:  Lost:     1.0930 Validation Accuracy:0.532200
# Epoch  2, CIFAR-10 Batch 4:  Lost:     1.2141 Validation Accuracy:0.560400
# Epoch  2, CIFAR-10 Batch 5:  Lost:     1.0948 Validation Accuracy:0.587600
# Epoch  3, CIFAR-10 Batch 1:  Lost:     1.2091 Validation Accuracy:0.561000
# Epoch  3, CIFAR-10 Batch 2:  Lost:     1.0369 Validation Accuracy:0.551600
# Epoch  3, CIFAR-10 Batch 3:  Lost:     0.9063 Validation Accuracy:0.596800
# Epoch  3, CIFAR-10 Batch 4:  Lost:     1.0446 Validation Accuracy:0.598800
# Epoch  3, CIFAR-10 Batch 5:  Lost:     0.9279 Validation Accuracy:0.603200
# Epoch  4, CIFAR-10 Batch 1:  Lost:     1.0497 Validation Accuracy:0.596200
# Epoch  4, CIFAR-10 Batch 2:  Lost:     0.8603 Validation Accuracy:0.599200
# Epoch  4, CIFAR-10 Batch 3:  Lost:     0.7098 Validation Accuracy:0.621200
# Epoch  4, CIFAR-10 Batch 4:  Lost:     0.8793 Validation Accuracy:0.619000
# Epoch  4, CIFAR-10 Batch 5:  Lost:     0.8480 Validation Accuracy:0.608400
# Epoch  5, CIFAR-10 Batch 1:  Lost:     1.0283 Validation Accuracy:0.590200
# Epoch  5, CIFAR-10 Batch 2:  Lost:     0.7650 Validation Accuracy:0.600200
# Epoch  5, CIFAR-10 Batch 3:  Lost:     0.6535 Validation Accuracy:0.620600
# Epoch  5, CIFAR-10 Batch 4:  Lost:     0.8100 Validation Accuracy:0.617400
# Epoch  5, CIFAR-10 Batch 5:  Lost:     0.7527 Validation Accuracy:0.633400
# Epoch  6, CIFAR-10 Batch 1:  Lost:     0.9379 Validation Accuracy:0.639000
# Epoch  6, CIFAR-10 Batch 2:  Lost:     0.7293 Validation Accuracy:0.611800
# Epoch  6, CIFAR-10 Batch 3:  Lost:     0.5391 Validation Accuracy:0.637600
# Epoch  6, CIFAR-10 Batch 4:  Lost:     0.7075 Validation Accuracy:0.627800
# Epoch  6, CIFAR-10 Batch 5:  Lost:     0.7397 Validation Accuracy:0.622400
# Epoch  7, CIFAR-10 Batch 1:  Lost:     0.8706 Validation Accuracy:0.626800
# Epoch  7, CIFAR-10 Batch 2:  Lost:     0.5753 Validation Accuracy:0.609800
# Epoch  7, CIFAR-10 Batch 3:  Lost:     0.5407 Validation Accuracy:0.616000
# Epoch  7, CIFAR-10 Batch 4:  Lost:     0.5729 Validation Accuracy:0.638200
# Epoch  7, CIFAR-10 Batch 5:  Lost:     0.6065 Validation Accuracy:0.624400
# Epoch  8, CIFAR-10 Batch 1:  Lost:     0.7532 Validation Accuracy:0.633800
# Epoch  8, CIFAR-10 Batch 2:  Lost:     0.4593 Validation Accuracy:0.620400
# Epoch  8, CIFAR-10 Batch 3:  Lost:     0.5094 Validation Accuracy:0.631600
# Epoch  8, CIFAR-10 Batch 4:  Lost:     0.4954 Validation Accuracy:0.638400
# Epoch  8, CIFAR-10 Batch 5:  Lost:     0.4874 Validation Accuracy:0.646400
# Epoch  9, CIFAR-10 Batch 1:  Lost:     0.7035 Validation Accuracy:0.619000
# Epoch  9, CIFAR-10 Batch 2:  Lost:     0.4961 Validation Accuracy:0.639400
# Epoch  9, CIFAR-10 Batch 3:  Lost:     0.4299 Validation Accuracy:0.636000
# Epoch  9, CIFAR-10 Batch 4:  Lost:     0.4767 Validation Accuracy:0.642600
# Epoch  9, CIFAR-10 Batch 5:  Lost:     0.4249 Validation Accuracy:0.648000
# Epoch 10, CIFAR-10 Batch 1:  Lost:     0.5380 Validation Accuracy:0.641600
# Epoch 10, CIFAR-10 Batch 2:  Lost:     0.5207 Validation Accuracy:0.613600
# Epoch 10, CIFAR-10 Batch 3:  Lost:     0.3695 Validation Accuracy:0.621800
# Epoch 10, CIFAR-10 Batch 4:  Lost:     0.4325 Validation Accuracy:0.640600
# Epoch 10, CIFAR-10 Batch 5:  Lost:     0.4967 Validation Accuracy:0.634200
# Epoch 11, CIFAR-10 Batch 1:  Lost:     0.5675 Validation Accuracy:0.626000
# Epoch 11, CIFAR-10 Batch 2:  Lost:     0.3831 Validation Accuracy:0.637400
# Epoch 11, CIFAR-10 Batch 3:  Lost:     0.3187 Validation Accuracy:0.637400
# Epoch 11, CIFAR-10 Batch 4:  Lost:     0.3510 Validation Accuracy:0.641800
# Epoch 11, CIFAR-10 Batch 5:  Lost:     0.3767 Validation Accuracy:0.643200
# Epoch 12, CIFAR-10 Batch 1:  Lost:     0.4422 Validation Accuracy:0.644000
# Epoch 12, CIFAR-10 Batch 2:  Lost:     0.3833 Validation Accuracy:0.625000
# Epoch 12, CIFAR-10 Batch 3:  Lost:     0.2636 Validation Accuracy:0.630000
# Epoch 12, CIFAR-10 Batch 4:  Lost:     0.3272 Validation Accuracy:0.637800
# Epoch 12, CIFAR-10 Batch 5:  Lost:     0.3612 Validation Accuracy:0.627400
# Epoch 13, CIFAR-10 Batch 1:  Lost:     0.4509 Validation Accuracy:0.633400
# Epoch 13, CIFAR-10 Batch 2:  Lost:     0.3269 Validation Accuracy:0.635600
# Epoch 13, CIFAR-10 Batch 3:  Lost:     0.2806 Validation Accuracy:0.599000
# Epoch 13, CIFAR-10 Batch 4:  Lost:     0.3033 Validation Accuracy:0.628200
# Epoch 13, CIFAR-10 Batch 5:  Lost:     0.3196 Validation Accuracy:0.627600
# Epoch 14, CIFAR-10 Batch 1:  Lost:     0.4412 Validation Accuracy:0.617800
# Epoch 14, CIFAR-10 Batch 2:  Lost:     0.2981 Validation Accuracy:0.637000
# Epoch 14, CIFAR-10 Batch 3:  Lost:     0.2002 Validation Accuracy:0.635200
# Epoch 14, CIFAR-10 Batch 4:  Lost:     0.2671 Validation Accuracy:0.637400
# Epoch 14, CIFAR-10 Batch 5:  Lost:     0.2815 Validation Accuracy:0.640800
# Epoch 15, CIFAR-10 Batch 1:  Lost:     0.3403 Validation Accuracy:0.628000
# Epoch 15, CIFAR-10 Batch 2:  Lost:     0.2553 Validation Accuracy:0.637000
# Epoch 15, CIFAR-10 Batch 3:  Lost:     0.2270 Validation Accuracy:0.630200
# Epoch 15, CIFAR-10 Batch 4:  Lost:     0.1774 Validation Accuracy:0.641800
# Epoch 15, CIFAR-10 Batch 5:  Lost:     0.2558 Validation Accuracy:0.625400
# Epoch 16, CIFAR-10 Batch 1:  Lost:     0.2970 Validation Accuracy:0.642000
# Epoch 16, CIFAR-10 Batch 2:  Lost:     0.2804 Validation Accuracy:0.634000
# Epoch 16, CIFAR-10 Batch 3:  Lost:     0.1882 Validation Accuracy:0.620800
# Epoch 16, CIFAR-10 Batch 4:  Lost:     0.2091 Validation Accuracy:0.631000
# Epoch 16, CIFAR-10 Batch 5:  Lost:     0.2833 Validation Accuracy:0.628600
# Epoch 17, CIFAR-10 Batch 1:  Lost:     0.2840 Validation Accuracy:0.642400
# Epoch 17, CIFAR-10 Batch 2:  Lost:     0.2341 Validation Accuracy:0.625000
# Epoch 17, CIFAR-10 Batch 3:  Lost:     0.1812 Validation Accuracy:0.617800
# Epoch 17, CIFAR-10 Batch 4:  Lost:     0.1617 Validation Accuracy:0.634600
# Epoch 17, CIFAR-10 Batch 5:  Lost:     0.1722 Validation Accuracy:0.606200
# Epoch 18, CIFAR-10 Batch 1:  Lost:     0.2886 Validation Accuracy:0.647800
# Epoch 18, CIFAR-10 Batch 2:  Lost:     0.2191 Validation Accuracy:0.610000
# Epoch 18, CIFAR-10 Batch 3:  Lost:     0.1983 Validation Accuracy:0.625800
# Epoch 18, CIFAR-10 Batch 4:  Lost:     0.1956 Validation Accuracy:0.619800
# Epoch 18, CIFAR-10 Batch 5:  Lost:     0.1618 Validation Accuracy:0.640600
# Epoch 19, CIFAR-10 Batch 1:  Lost:     0.2504 Validation Accuracy:0.633400
# Epoch 19, CIFAR-10 Batch 2:  Lost:     0.2185 Validation Accuracy:0.632200
# Epoch 19, CIFAR-10 Batch 3:  Lost:     0.1446 Validation Accuracy:0.608000
# Epoch 19, CIFAR-10 Batch 4:  Lost:     0.1325 Validation Accuracy:0.628200
# Epoch 19, CIFAR-10 Batch 5:  Lost:     0.1652 Validation Accuracy:0.643800
# Epoch 20, CIFAR-10 Batch 1:  Lost:     0.2341 Validation Accuracy:0.630000
# Epoch 20, CIFAR-10 Batch 2:  Lost:     0.1786 Validation Accuracy:0.635000
# Epoch 20, CIFAR-10 Batch 3:  Lost:     0.1241 Validation Accuracy:0.618400
# Epoch 20, CIFAR-10 Batch 4:  Lost:     0.1235 Validation Accuracy:0.636200
# Epoch 20, CIFAR-10 Batch 5:  Lost:     0.1373 Validation Accuracy:0.647600
# Epoch 21, CIFAR-10 Batch 1:  Lost:     0.2135 Validation Accuracy:0.638600
# Epoch 21, CIFAR-10 Batch 2:  Lost:     0.1557 Validation Accuracy:0.640200
# Epoch 21, CIFAR-10 Batch 3:  Lost:     0.1413 Validation Accuracy:0.608000
# Epoch 21, CIFAR-10 Batch 4:  Lost:     0.1203 Validation Accuracy:0.621600
# Epoch 21, CIFAR-10 Batch 5:  Lost:     0.1621 Validation Accuracy:0.640200
# Epoch 22, CIFAR-10 Batch 1:  Lost:     0.2075 Validation Accuracy:0.617200
# Epoch 22, CIFAR-10 Batch 2:  Lost:     0.1486 Validation Accuracy:0.632000
# Epoch 22, CIFAR-10 Batch 3:  Lost:     0.1175 Validation Accuracy:0.606800
# Epoch 22, CIFAR-10 Batch 4:  Lost:     0.0972 Validation Accuracy:0.633000
# Epoch 22, CIFAR-10 Batch 5:  Lost:     0.1277 Validation Accuracy:0.634400
# Epoch 23, CIFAR-10 Batch 1:  Lost:     0.2274 Validation Accuracy:0.630800
# Epoch 23, CIFAR-10 Batch 2:  Lost:     0.1345 Validation Accuracy:0.631600
# Epoch 23, CIFAR-10 Batch 3:  Lost:     0.0589 Validation Accuracy:0.634000
# Epoch 23, CIFAR-10 Batch 4:  Lost:     0.1042 Validation Accuracy:0.630600
# Epoch 23, CIFAR-10 Batch 5:  Lost:     0.1529 Validation Accuracy:0.625800
# Epoch 24, CIFAR-10 Batch 1:  Lost:     0.2745 Validation Accuracy:0.638400
# Epoch 24, CIFAR-10 Batch 2:  Lost:     0.1114 Validation Accuracy:0.637400
# Epoch 24, CIFAR-10 Batch 3:  Lost:     0.0933 Validation Accuracy:0.621400
# Epoch 24, CIFAR-10 Batch 4:  Lost:     0.1102 Validation Accuracy:0.610000
# Epoch 24, CIFAR-10 Batch 5:  Lost:     0.1116 Validation Accuracy:0.624200
# Epoch 25, CIFAR-10 Batch 1:  Lost:     0.1277 Validation Accuracy:0.638800
# Epoch 25, CIFAR-10 Batch 2:  Lost:     0.0860 Validation Accuracy:0.631200
# Epoch 25, CIFAR-10 Batch 3:  Lost:     0.0712 Validation Accuracy:0.613800
# Epoch 25, CIFAR-10 Batch 4:  Lost:     0.0945 Validation Accuracy:0.621200
# Epoch 25, CIFAR-10 Batch 5:  Lost:     0.1284 Validation Accuracy:0.632600
# Epoch 26, CIFAR-10 Batch 1:  Lost:     0.2402 Validation Accuracy:0.624400
# Epoch 26, CIFAR-10 Batch 2:  Lost:     0.1043 Validation Accuracy:0.626200
# Epoch 26, CIFAR-10 Batch 3:  Lost:     0.0712 Validation Accuracy:0.632800
# Epoch 26, CIFAR-10 Batch 4:  Lost:     0.1020 Validation Accuracy:0.625000
# Epoch 26, CIFAR-10 Batch 5:  Lost:     0.0765 Validation Accuracy:0.637000
# Epoch 27, CIFAR-10 Batch 1:  Lost:     0.1804 Validation Accuracy:0.618200
# Epoch 27, CIFAR-10 Batch 2:  Lost:     0.0984 Validation Accuracy:0.618600
# Epoch 27, CIFAR-10 Batch 3:  Lost:     0.0574 Validation Accuracy:0.624000
# Epoch 27, CIFAR-10 Batch 4:  Lost:     0.0649 Validation Accuracy:0.632400
# Epoch 27, CIFAR-10 Batch 5:  Lost:     0.1125 Validation Accuracy:0.625400
# Epoch 28, CIFAR-10 Batch 1:  Lost:     0.1241 Validation Accuracy:0.631400
# Epoch 28, CIFAR-10 Batch 2:  Lost:     0.0747 Validation Accuracy:0.618400
# Epoch 28, CIFAR-10 Batch 3:  Lost:     0.0454 Validation Accuracy:0.621400
# Epoch 28, CIFAR-10 Batch 4:  Lost:     0.0607 Validation Accuracy:0.622200
# Epoch 28, CIFAR-10 Batch 5:  Lost:     0.1026 Validation Accuracy:0.632200
# Epoch 29, CIFAR-10 Batch 1:  Lost:     0.1034 Validation Accuracy:0.632000
# Epoch 29, CIFAR-10 Batch 2:  Lost:     0.0924 Validation Accuracy:0.627200
# Epoch 29, CIFAR-10 Batch 3:  Lost:     0.0303 Validation Accuracy:0.635000
# Epoch 29, CIFAR-10 Batch 4:  Lost:     0.0943 Validation Accuracy:0.619200
# Epoch 29, CIFAR-10 Batch 5:  Lost:     0.0663 Validation Accuracy:0.625800
# Epoch 30, CIFAR-10 Batch 1:  Lost:     0.1441 Validation Accuracy:0.612800
# Epoch 30, CIFAR-10 Batch 2:  Lost:     0.0635 Validation Accuracy:0.636800
# Epoch 30, CIFAR-10 Batch 3:  Lost:     0.0240 Validation Accuracy:0.626000
# Epoch 30, CIFAR-10 Batch 4:  Lost:     0.0897 Validation Accuracy:0.620200
# Epoch 30, CIFAR-10 Batch 5:  Lost:     0.0844 Validation Accuracy:0.624400
# Epoch 31, CIFAR-10 Batch 1:  Lost:     0.1405 Validation Accuracy:0.605600
# Epoch 31, CIFAR-10 Batch 2:  Lost:     0.0412 Validation Accuracy:0.622800
# Epoch 31, CIFAR-10 Batch 3:  Lost:     0.0553 Validation Accuracy:0.603200
# Epoch 31, CIFAR-10 Batch 4:  Lost:     0.0912 Validation Accuracy:0.611400
# Epoch 31, CIFAR-10 Batch 5:  Lost:     0.0733 Validation Accuracy:0.622600
# Epoch 32, CIFAR-10 Batch 1:  Lost:     0.0833 Validation Accuracy:0.603400
# Epoch 32, CIFAR-10 Batch 2:  Lost:     0.0766 Validation Accuracy:0.625000
# Epoch 32, CIFAR-10 Batch 3:  Lost:     0.0483 Validation Accuracy:0.615800
# Epoch 32, CIFAR-10 Batch 4:  Lost:     0.0620 Validation Accuracy:0.615800
# Epoch 32, CIFAR-10 Batch 5:  Lost:     0.0750 Validation Accuracy:0.622200
# Epoch 33, CIFAR-10 Batch 1:  Lost:     0.0755 Validation Accuracy:0.602800
# Epoch 33, CIFAR-10 Batch 2:  Lost:     0.0870 Validation Accuracy:0.619000
# Epoch 33, CIFAR-10 Batch 3:  Lost:     0.0689 Validation Accuracy:0.610800
# Epoch 33, CIFAR-10 Batch 4:  Lost:     0.0519 Validation Accuracy:0.620000
# Epoch 33, CIFAR-10 Batch 5:  Lost:     0.1095 Validation Accuracy:0.620800
# Epoch 34, CIFAR-10 Batch 1:  Lost:     0.0884 Validation Accuracy:0.603400
# Epoch 34, CIFAR-10 Batch 2:  Lost:     0.0341 Validation Accuracy:0.627400
# Epoch 34, CIFAR-10 Batch 3:  Lost:     0.0345 Validation Accuracy:0.616600
# Epoch 34, CIFAR-10 Batch 4:  Lost:     0.0423 Validation Accuracy:0.622400
# Epoch 34, CIFAR-10 Batch 5:  Lost:     0.0586 Validation Accuracy:0.615600
# Epoch 35, CIFAR-10 Batch 1:  Lost:     0.1434 Validation Accuracy:0.608600
# Epoch 35, CIFAR-10 Batch 2:  Lost:     0.0438 Validation Accuracy:0.613600
# Epoch 35, CIFAR-10 Batch 3:  Lost:     0.0431 Validation Accuracy:0.605200
# Epoch 35, CIFAR-10 Batch 4:  Lost:     0.0402 Validation Accuracy:0.616000
# Epoch 35, CIFAR-10 Batch 5:  Lost:     0.0944 Validation Accuracy:0.618200
# Epoch 36, CIFAR-10 Batch 1:  Lost:     0.0930 Validation Accuracy:0.625000
# Epoch 36, CIFAR-10 Batch 2:  Lost:     0.0718 Validation Accuracy:0.604000
# Epoch 36, CIFAR-10 Batch 3:  Lost:     0.0267 Validation Accuracy:0.599200
# Epoch 36, CIFAR-10 Batch 4:  Lost:     0.0739 Validation Accuracy:0.616000
# Epoch 36, CIFAR-10 Batch 5:  Lost:     0.0367 Validation Accuracy:0.605000
# Epoch 37, CIFAR-10 Batch 1:  Lost:     0.1013 Validation Accuracy:0.627600
# Epoch 37, CIFAR-10 Batch 2:  Lost:     0.0976 Validation Accuracy:0.607000
# Epoch 37, CIFAR-10 Batch 3:  Lost:     0.0289 Validation Accuracy:0.599200
# Epoch 37, CIFAR-10 Batch 4:  Lost:     0.0751 Validation Accuracy:0.607600
# Epoch 37, CIFAR-10 Batch 5:  Lost:     0.1133 Validation Accuracy:0.593400
# Epoch 38, CIFAR-10 Batch 1:  Lost:     0.0919 Validation Accuracy:0.603600
# Epoch 38, CIFAR-10 Batch 2:  Lost:     0.0544 Validation Accuracy:0.600400
# Epoch 38, CIFAR-10 Batch 3:  Lost:     0.0357 Validation Accuracy:0.616400
# Epoch 38, CIFAR-10 Batch 4:  Lost:     0.0452 Validation Accuracy:0.605000
# Epoch 38, CIFAR-10 Batch 5:  Lost:     0.0368 Validation Accuracy:0.614800
# Epoch 39, CIFAR-10 Batch 1:  Lost:     0.0973 Validation Accuracy:0.612600
# Epoch 39, CIFAR-10 Batch 2:  Lost:     0.0770 Validation Accuracy:0.604200
# Epoch 39, CIFAR-10 Batch 3:  Lost:     0.0466 Validation Accuracy:0.610600
# Epoch 39, CIFAR-10 Batch 4:  Lost:     0.0498 Validation Accuracy:0.608000
# Epoch 39, CIFAR-10 Batch 5:  Lost:     0.0406 Validation Accuracy:0.618400
# Epoch 40, CIFAR-10 Batch 1:  Lost:     0.0592 Validation Accuracy:0.628400
# Epoch 40, CIFAR-10 Batch 2:  Lost:     0.0264 Validation Accuracy:0.618200
# Epoch 40, CIFAR-10 Batch 3:  Lost:     0.0423 Validation Accuracy:0.599200
# Epoch 40, CIFAR-10 Batch 4:  Lost:     0.0317 Validation Accuracy:0.623000
# Epoch 40, CIFAR-10 Batch 5:  Lost:     0.0319 Validation Accuracy:0.620200
# Epoch 41, CIFAR-10 Batch 1:  Lost:     0.0551 Validation Accuracy:0.610800
# Epoch 41, CIFAR-10 Batch 2:  Lost:     0.0389 Validation Accuracy:0.594000
# Epoch 41, CIFAR-10 Batch 3:  Lost:     0.0309 Validation Accuracy:0.598000
# Epoch 41, CIFAR-10 Batch 4:  Lost:     0.0275 Validation Accuracy:0.617400
# Epoch 41, CIFAR-10 Batch 5:  Lost:     0.0239 Validation Accuracy:0.616000
# Epoch 42, CIFAR-10 Batch 1:  Lost:     0.0768 Validation Accuracy:0.606200
# Epoch 42, CIFAR-10 Batch 2:  Lost:     0.0317 Validation Accuracy:0.598200
# Epoch 42, CIFAR-10 Batch 3:  Lost:     0.0307 Validation Accuracy:0.606200
# Epoch 42, CIFAR-10 Batch 4:  Lost:     0.0452 Validation Accuracy:0.609600
# Epoch 42, CIFAR-10 Batch 5:  Lost:     0.0235 Validation Accuracy:0.601200
# Epoch 43, CIFAR-10 Batch 1:  Lost:     0.0514 Validation Accuracy:0.617200
# Epoch 43, CIFAR-10 Batch 2:  Lost:     0.0277 Validation Accuracy:0.598000
# Epoch 43, CIFAR-10 Batch 3:  Lost:     0.0242 Validation Accuracy:0.620200
# Epoch 43, CIFAR-10 Batch 4:  Lost:     0.0222 Validation Accuracy:0.616600
# Epoch 43, CIFAR-10 Batch 5:  Lost:     0.0356 Validation Accuracy:0.595200
# Epoch 44, CIFAR-10 Batch 1:  Lost:     0.0589 Validation Accuracy:0.610600
# Epoch 44, CIFAR-10 Batch 2:  Lost:     0.0209 Validation Accuracy:0.614800
# Epoch 44, CIFAR-10 Batch 3:  Lost:     0.0345 Validation Accuracy:0.615200
# Epoch 44, CIFAR-10 Batch 4:  Lost:     0.0459 Validation Accuracy:0.603200
# Epoch 44, CIFAR-10 Batch 5:  Lost:     0.0283 Validation Accuracy:0.603400
# Epoch 45, CIFAR-10 Batch 1:  Lost:     0.0594 Validation Accuracy:0.609800
# Epoch 45, CIFAR-10 Batch 2:  Lost:     0.0134 Validation Accuracy:0.614800
# Epoch 45, CIFAR-10 Batch 3:  Lost:     0.0419 Validation Accuracy:0.597600
# Epoch 45, CIFAR-10 Batch 4:  Lost:     0.0365 Validation Accuracy:0.606400
# Epoch 45, CIFAR-10 Batch 5:  Lost:     0.0257 Validation Accuracy:0.602600
# Epoch 46, CIFAR-10 Batch 1:  Lost:     0.0293 Validation Accuracy:0.615800
# Epoch 46, CIFAR-10 Batch 2:  Lost:     0.0387 Validation Accuracy:0.613600
# Epoch 46, CIFAR-10 Batch 3:  Lost:     0.0198 Validation Accuracy:0.605200
# Epoch 46, CIFAR-10 Batch 4:  Lost:     0.0427 Validation Accuracy:0.606400
# Epoch 46, CIFAR-10 Batch 5:  Lost:     0.0234 Validation Accuracy:0.607000
# Epoch 47, CIFAR-10 Batch 1:  Lost:     0.0293 Validation Accuracy:0.618200
# Epoch 47, CIFAR-10 Batch 2:  Lost:     0.0170 Validation Accuracy:0.602400
# Epoch 47, CIFAR-10 Batch 3:  Lost:     0.0181 Validation Accuracy:0.620000
# Epoch 47, CIFAR-10 Batch 4:  Lost:     0.0472 Validation Accuracy:0.613600
# Epoch 47, CIFAR-10 Batch 5:  Lost:     0.0369 Validation Accuracy:0.602200
# Epoch 48, CIFAR-10 Batch 1:  Lost:     0.0263 Validation Accuracy:0.620200
# Epoch 48, CIFAR-10 Batch 2:  Lost:     0.0101 Validation Accuracy:0.613000
# Epoch 48, CIFAR-10 Batch 3:  Lost:     0.0389 Validation Accuracy:0.615400
# Epoch 48, CIFAR-10 Batch 4:  Lost:     0.0334 Validation Accuracy:0.612600
# Epoch 48, CIFAR-10 Batch 5:  Lost:     0.0329 Validation Accuracy:0.594800
# Epoch 49, CIFAR-10 Batch 1:  Lost:     0.0452 Validation Accuracy:0.617000
# Epoch 49, CIFAR-10 Batch 2:  Lost:     0.0269 Validation Accuracy:0.598400
# Epoch 49, CIFAR-10 Batch 3:  Lost:     0.0338 Validation Accuracy:0.613000
# Epoch 49, CIFAR-10 Batch 4:  Lost:     0.0415 Validation Accuracy:0.618800
# Epoch 49, CIFAR-10 Batch 5:  Lost:     0.0262 Validation Accuracy:0.602600
# Epoch 50, CIFAR-10 Batch 1:  Lost:     0.0238 Validation Accuracy:0.619200
# Epoch 50, CIFAR-10 Batch 2:  Lost:     0.0499 Validation Accuracy:0.609800
# Epoch 50, CIFAR-10 Batch 3:  Lost:     0.0218 Validation Accuracy:0.617200
# Epoch 50, CIFAR-10 Batch 4:  Lost:     0.0370 Validation Accuracy:0.612000
# Epoch 50, CIFAR-10 Batch 5:  Lost:     0.0152 Validation Accuracy:0.587200
# Epoch 51, CIFAR-10 Batch 1:  Lost:     0.0213 Validation Accuracy:0.619600
# Epoch 51, CIFAR-10 Batch 2:  Lost:     0.0479 Validation Accuracy:0.614000
# Epoch 51, CIFAR-10 Batch 3:  Lost:     0.0170 Validation Accuracy:0.608000
# Epoch 51, CIFAR-10 Batch 4:  Lost:     0.0568 Validation Accuracy:0.611000
# Epoch 51, CIFAR-10 Batch 5:  Lost:     0.0470 Validation Accuracy:0.579200
# Epoch 52, CIFAR-10 Batch 1:  Lost:     0.0148 Validation Accuracy:0.610800
# Epoch 52, CIFAR-10 Batch 2:  Lost:     0.0174 Validation Accuracy:0.611600
# Epoch 52, CIFAR-10 Batch 3:  Lost:     0.0056 Validation Accuracy:0.622000
# Epoch 52, CIFAR-10 Batch 4:  Lost:     0.0314 Validation Accuracy:0.602600
# Epoch 52, CIFAR-10 Batch 5:  Lost:     0.0125 Validation Accuracy:0.597200
# Epoch 53, CIFAR-10 Batch 1:  Lost:     0.0180 Validation Accuracy:0.615200
# Epoch 53, CIFAR-10 Batch 2:  Lost:     0.0445 Validation Accuracy:0.608000
# Epoch 53, CIFAR-10 Batch 3:  Lost:     0.0191 Validation Accuracy:0.616200
# Epoch 53, CIFAR-10 Batch 4:  Lost:     0.0308 Validation Accuracy:0.613800
# Epoch 53, CIFAR-10 Batch 5:  Lost:     0.0479 Validation Accuracy:0.591600
# Epoch 54, CIFAR-10 Batch 1:  Lost:     0.0288 Validation Accuracy:0.622000
# Epoch 54, CIFAR-10 Batch 2:  Lost:     0.0221 Validation Accuracy:0.616000
# Epoch 54, CIFAR-10 Batch 3:  Lost:     0.0110 Validation Accuracy:0.615200
# Epoch 54, CIFAR-10 Batch 4:  Lost:     0.0185 Validation Accuracy:0.620000
# Epoch 54, CIFAR-10 Batch 5:  Lost:     0.0569 Validation Accuracy:0.566400
# Epoch 55, CIFAR-10 Batch 1:  Lost:     0.0325 Validation Accuracy:0.624200
# Epoch 55, CIFAR-10 Batch 2:  Lost:     0.0080 Validation Accuracy:0.614600
# Epoch 55, CIFAR-10 Batch 3:  Lost:     0.0089 Validation Accuracy:0.614800
# Epoch 55, CIFAR-10 Batch 4:  Lost:     0.0103 Validation Accuracy:0.611600
# Epoch 55, CIFAR-10 Batch 5:  Lost:     0.0131 Validation Accuracy:0.612600
# Epoch 56, CIFAR-10 Batch 1:  Lost:     0.0192 Validation Accuracy:0.617000
# Epoch 56, CIFAR-10 Batch 2:  Lost:     0.0232 Validation Accuracy:0.610800
# Epoch 56, CIFAR-10 Batch 3:  Lost:     0.0077 Validation Accuracy:0.619400
# Epoch 56, CIFAR-10 Batch 4:  Lost:     0.0278 Validation Accuracy:0.622000
# Epoch 56, CIFAR-10 Batch 5:  Lost:     0.0155 Validation Accuracy:0.610400
# Epoch 57, CIFAR-10 Batch 1:  Lost:     0.0175 Validation Accuracy:0.621000
# Epoch 57, CIFAR-10 Batch 2:  Lost:     0.0282 Validation Accuracy:0.611800
# Epoch 57, CIFAR-10 Batch 3:  Lost:     0.0116 Validation Accuracy:0.618000
# Epoch 57, CIFAR-10 Batch 4:  Lost:     0.0273 Validation Accuracy:0.594400
# Epoch 57, CIFAR-10 Batch 5:  Lost:     0.0151 Validation Accuracy:0.609400
# Epoch 58, CIFAR-10 Batch 1:  Lost:     0.0215 Validation Accuracy:0.620000
# Epoch 58, CIFAR-10 Batch 2:  Lost:     0.0185 Validation Accuracy:0.605200
# Epoch 58, CIFAR-10 Batch 3:  Lost:     0.0127 Validation Accuracy:0.611800
# Epoch 58, CIFAR-10 Batch 4:  Lost:     0.0219 Validation Accuracy:0.607400
# Epoch 58, CIFAR-10 Batch 5:  Lost:     0.0164 Validation Accuracy:0.607000
# Epoch 59, CIFAR-10 Batch 1:  Lost:     0.0263 Validation Accuracy:0.613600
# Epoch 59, CIFAR-10 Batch 2:  Lost:     0.0080 Validation Accuracy:0.616200
# Epoch 59, CIFAR-10 Batch 3:  Lost:     0.0282 Validation Accuracy:0.606800
# Epoch 59, CIFAR-10 Batch 4:  Lost:     0.0179 Validation Accuracy:0.609200
# Epoch 59, CIFAR-10 Batch 5:  Lost:     0.0139 Validation Accuracy:0.599400
# Epoch 60, CIFAR-10 Batch 1:  Lost:     0.0212 Validation Accuracy:0.615200
# Epoch 60, CIFAR-10 Batch 2:  Lost:     0.0182 Validation Accuracy:0.585000
# Epoch 60, CIFAR-10 Batch 3:  Lost:     0.0151 Validation Accuracy:0.614200
# Epoch 60, CIFAR-10 Batch 4:  Lost:     0.0136 Validation Accuracy:0.606000
# Epoch 60, CIFAR-10 Batch 5:  Lost:     0.0195 Validation Accuracy:0.602200
# Epoch 61, CIFAR-10 Batch 1:  Lost:     0.0157 Validation Accuracy:0.604400
# Epoch 61, CIFAR-10 Batch 2:  Lost:     0.0225 Validation Accuracy:0.613200
# Epoch 61, CIFAR-10 Batch 3:  Lost:     0.0312 Validation Accuracy:0.606800
# Epoch 61, CIFAR-10 Batch 4:  Lost:     0.0101 Validation Accuracy:0.602200
# Epoch 61, CIFAR-10 Batch 5:  Lost:     0.0358 Validation Accuracy:0.598400
# Epoch 62, CIFAR-10 Batch 1:  Lost:     0.0097 Validation Accuracy:0.621400
# Epoch 62, CIFAR-10 Batch 2:  Lost:     0.0182 Validation Accuracy:0.611000
# Epoch 62, CIFAR-10 Batch 3:  Lost:     0.0286 Validation Accuracy:0.618200
# Epoch 62, CIFAR-10 Batch 4:  Lost:     0.0078 Validation Accuracy:0.610800
# Epoch 62, CIFAR-10 Batch 5:  Lost:     0.0097 Validation Accuracy:0.606200
# Epoch 63, CIFAR-10 Batch 1:  Lost:     0.0092 Validation Accuracy:0.614400
# Epoch 63, CIFAR-10 Batch 2:  Lost:     0.0136 Validation Accuracy:0.598000
# Epoch 63, CIFAR-10 Batch 3:  Lost:     0.0071 Validation Accuracy:0.607200
# Epoch 63, CIFAR-10 Batch 4:  Lost:     0.0080 Validation Accuracy:0.596000
# Epoch 63, CIFAR-10 Batch 5:  Lost:     0.0090 Validation Accuracy:0.607000
# Epoch 64, CIFAR-10 Batch 1:  Lost:     0.0131 Validation Accuracy:0.610000
# Epoch 64, CIFAR-10 Batch 2:  Lost:     0.0287 Validation Accuracy:0.596200
# Epoch 64, CIFAR-10 Batch 3:  Lost:     0.0202 Validation Accuracy:0.612600
# Epoch 64, CIFAR-10 Batch 4:  Lost:     0.0233 Validation Accuracy:0.578200
# Epoch 64, CIFAR-10 Batch 5:  Lost:     0.0110 Validation Accuracy:0.595200
# Epoch 65, CIFAR-10 Batch 1:  Lost:     0.0146 Validation Accuracy:0.613400
# Epoch 65, CIFAR-10 Batch 2:  Lost:     0.0281 Validation Accuracy:0.585400
# Epoch 65, CIFAR-10 Batch 3:  Lost:     0.0057 Validation Accuracy:0.605800
# Epoch 65, CIFAR-10 Batch 4:  Lost:     0.0108 Validation Accuracy:0.606400
# Epoch 65, CIFAR-10 Batch 5:  Lost:     0.0172 Validation Accuracy:0.606000
# Epoch 66, CIFAR-10 Batch 1:  Lost:     0.0265 Validation Accuracy:0.616000
# Epoch 66, CIFAR-10 Batch 2:  Lost:     0.0131 Validation Accuracy:0.603600
# Epoch 66, CIFAR-10 Batch 3:  Lost:     0.0089 Validation Accuracy:0.614000
# Epoch 66, CIFAR-10 Batch 4:  Lost:     0.0136 Validation Accuracy:0.598000
# Epoch 66, CIFAR-10 Batch 5:  Lost:     0.0103 Validation Accuracy:0.603200
# Epoch 67, CIFAR-10 Batch 1:  Lost:     0.0101 Validation Accuracy:0.604200
# Epoch 67, CIFAR-10 Batch 2:  Lost:     0.0086 Validation Accuracy:0.613000
# Epoch 67, CIFAR-10 Batch 3:  Lost:     0.0064 Validation Accuracy:0.606800
# Epoch 67, CIFAR-10 Batch 4:  Lost:     0.0116 Validation Accuracy:0.602200
# Epoch 67, CIFAR-10 Batch 5:  Lost:     0.0195 Validation Accuracy:0.605000
# Epoch 68, CIFAR-10 Batch 1:  Lost:     0.0357 Validation Accuracy:0.592000
# Epoch 68, CIFAR-10 Batch 2:  Lost:     0.0061 Validation Accuracy:0.604400
# Epoch 68, CIFAR-10 Batch 3:  Lost:     0.0062 Validation Accuracy:0.604600
# Epoch 68, CIFAR-10 Batch 4:  Lost:     0.0231 Validation Accuracy:0.602800
# Epoch 68, CIFAR-10 Batch 5:  Lost:     0.0064 Validation Accuracy:0.602800
# Epoch 69, CIFAR-10 Batch 1:  Lost:     0.0084 Validation Accuracy:0.598800
# Epoch 69, CIFAR-10 Batch 2:  Lost:     0.0136 Validation Accuracy:0.593200
# Epoch 69, CIFAR-10 Batch 3:  Lost:     0.0025 Validation Accuracy:0.617600
# Epoch 69, CIFAR-10 Batch 4:  Lost:     0.0167 Validation Accuracy:0.604000
# Epoch 69, CIFAR-10 Batch 5:  Lost:     0.0212 Validation Accuracy:0.605800
# Epoch 70, CIFAR-10 Batch 1:  Lost:     0.0399 Validation Accuracy:0.614800
# Epoch 70, CIFAR-10 Batch 2:  Lost:     0.0080 Validation Accuracy:0.613800
# Epoch 70, CIFAR-10 Batch 3:  Lost:     0.0114 Validation Accuracy:0.602600
# Epoch 70, CIFAR-10 Batch 4:  Lost:     0.0106 Validation Accuracy:0.610800
# Epoch 70, CIFAR-10 Batch 5:  Lost:     0.0049 Validation Accuracy:0.605400
# Epoch 71, CIFAR-10 Batch 1:  Lost:     0.0256 Validation Accuracy:0.604600
# Epoch 71, CIFAR-10 Batch 2:  Lost:     0.0170 Validation Accuracy:0.606000
# Epoch 71, CIFAR-10 Batch 3:  Lost:     0.0093 Validation Accuracy:0.609200
# Epoch 71, CIFAR-10 Batch 4:  Lost:     0.0069 Validation Accuracy:0.605000
# Epoch 71, CIFAR-10 Batch 5:  Lost:     0.0054 Validation Accuracy:0.609600
# Epoch 72, CIFAR-10 Batch 1:  Lost:     0.0105 Validation Accuracy:0.610000
# Epoch 72, CIFAR-10 Batch 2:  Lost:     0.0184 Validation Accuracy:0.608200
# Epoch 72, CIFAR-10 Batch 3:  Lost:     0.0378 Validation Accuracy:0.591600
# Epoch 72, CIFAR-10 Batch 4:  Lost:     0.0145 Validation Accuracy:0.598600
# Epoch 72, CIFAR-10 Batch 5:  Lost:     0.0103 Validation Accuracy:0.604400
# Epoch 73, CIFAR-10 Batch 1:  Lost:     0.0114 Validation Accuracy:0.601000
# Epoch 73, CIFAR-10 Batch 2:  Lost:     0.0191 Validation Accuracy:0.609400
# Epoch 73, CIFAR-10 Batch 3:  Lost:     0.0064 Validation Accuracy:0.599800
# Epoch 73, CIFAR-10 Batch 4:  Lost:     0.0202 Validation Accuracy:0.594000
# Epoch 73, CIFAR-10 Batch 5:  Lost:     0.0048 Validation Accuracy:0.591200
# Epoch 74, CIFAR-10 Batch 1:  Lost:     0.0067 Validation Accuracy:0.614400
# Epoch 74, CIFAR-10 Batch 2:  Lost:     0.0068 Validation Accuracy:0.612200
# Epoch 74, CIFAR-10 Batch 3:  Lost:     0.0039 Validation Accuracy:0.609400
# Epoch 74, CIFAR-10 Batch 4:  Lost:     0.0202 Validation Accuracy:0.602400
# Epoch 74, CIFAR-10 Batch 5:  Lost:     0.0090 Validation Accuracy:0.609400
# Epoch 75, CIFAR-10 Batch 1:  Lost:     0.0108 Validation Accuracy:0.609800
# Epoch 75, CIFAR-10 Batch 2:  Lost:     0.0063 Validation Accuracy:0.609600
# Epoch 75, CIFAR-10 Batch 3:  Lost:     0.0035 Validation Accuracy:0.610400
# Epoch 75, CIFAR-10 Batch 4:  Lost:     0.0116 Validation Accuracy:0.600200
# Epoch 75, CIFAR-10 Batch 5:  Lost:     0.0096 Validation Accuracy:0.602200
# Epoch 76, CIFAR-10 Batch 1:  Lost:     0.0156 Validation Accuracy:0.604400
# Epoch 76, CIFAR-10 Batch 2:  Lost:     0.0228 Validation Accuracy:0.594600
# Epoch 76, CIFAR-10 Batch 3:  Lost:     0.0151 Validation Accuracy:0.590000
# Epoch 76, CIFAR-10 Batch 4:  Lost:     0.0191 Validation Accuracy:0.601600
# Epoch 76, CIFAR-10 Batch 5:  Lost:     0.0309 Validation Accuracy:0.587400
# Epoch 77, CIFAR-10 Batch 1:  Lost:     0.0121 Validation Accuracy:0.604400
# Epoch 77, CIFAR-10 Batch 2:  Lost:     0.0404 Validation Accuracy:0.593000
# Epoch 77, CIFAR-10 Batch 3:  Lost:     0.0015 Validation Accuracy:0.611800
# Epoch 77, CIFAR-10 Batch 4:  Lost:     0.0175 Validation Accuracy:0.604800
# Epoch 77, CIFAR-10 Batch 5:  Lost:     0.0029 Validation Accuracy:0.600800
# Epoch 78, CIFAR-10 Batch 1:  Lost:     0.0217 Validation Accuracy:0.598600
# Epoch 78, CIFAR-10 Batch 2:  Lost:     0.0167 Validation Accuracy:0.603200
# Epoch 78, CIFAR-10 Batch 3:  Lost:     0.0020 Validation Accuracy:0.591400
# Epoch 78, CIFAR-10 Batch 4:  Lost:     0.0137 Validation Accuracy:0.604000
# Epoch 78, CIFAR-10 Batch 5:  Lost:     0.0097 Validation Accuracy:0.597600
# Epoch 79, CIFAR-10 Batch 1:  Lost:     0.0040 Validation Accuracy:0.615600
# Epoch 79, CIFAR-10 Batch 2:  Lost:     0.0046 Validation Accuracy:0.604400
# Epoch 79, CIFAR-10 Batch 3:  Lost:     0.0025 Validation Accuracy:0.611000
# Epoch 79, CIFAR-10 Batch 4:  Lost:     0.0212 Validation Accuracy:0.598800
# Epoch 79, CIFAR-10 Batch 5:  Lost:     0.0125 Validation Accuracy:0.608600
# Epoch 80, CIFAR-10 Batch 1:  Lost:     0.0133 Validation Accuracy:0.605200
# Epoch 80, CIFAR-10 Batch 2:  Lost:     0.0084 Validation Accuracy:0.602600
# Epoch 80, CIFAR-10 Batch 3:  Lost:     0.0005 Validation Accuracy:0.609000
# Epoch 80, CIFAR-10 Batch 4:  Lost:     0.0061 Validation Accuracy:0.609000
# Epoch 80, CIFAR-10 Batch 5:  Lost:     0.0088 Validation Accuracy:0.599800
# Epoch 81, CIFAR-10 Batch 1:  Lost:     0.0058 Validation Accuracy:0.611000
# Epoch 81, CIFAR-10 Batch 2:  Lost:     0.0130 Validation Accuracy:0.607000
# Epoch 81, CIFAR-10 Batch 3:  Lost:     0.0078 Validation Accuracy:0.599200
# Epoch 81, CIFAR-10 Batch 4:  Lost:     0.0107 Validation Accuracy:0.592800
# Epoch 81, CIFAR-10 Batch 5:  Lost:     0.0149 Validation Accuracy:0.606800
# Epoch 82, CIFAR-10 Batch 1:  Lost:     0.0116 Validation Accuracy:0.599200
# Epoch 82, CIFAR-10 Batch 2:  Lost:     0.0068 Validation Accuracy:0.609200
# Epoch 82, CIFAR-10 Batch 3:  Lost:     0.0010 Validation Accuracy:0.613600
# Epoch 82, CIFAR-10 Batch 4:  Lost:     0.0086 Validation Accuracy:0.606400
# Epoch 82, CIFAR-10 Batch 5:  Lost:     0.0067 Validation Accuracy:0.612000
# Epoch 83, CIFAR-10 Batch 1:  Lost:     0.0107 Validation Accuracy:0.598200
# Epoch 83, CIFAR-10 Batch 2:  Lost:     0.0049 Validation Accuracy:0.590800
# Epoch 83, CIFAR-10 Batch 3:  Lost:     0.0060 Validation Accuracy:0.606800
# Epoch 83, CIFAR-10 Batch 4:  Lost:     0.0058 Validation Accuracy:0.600800
# Epoch 83, CIFAR-10 Batch 5:  Lost:     0.0033 Validation Accuracy:0.605000
# Epoch 84, CIFAR-10 Batch 1:  Lost:     0.0084 Validation Accuracy:0.603600
# Epoch 84, CIFAR-10 Batch 2:  Lost:     0.0150 Validation Accuracy:0.607000
# Epoch 84, CIFAR-10 Batch 3:  Lost:     0.0129 Validation Accuracy:0.592000
# Epoch 84, CIFAR-10 Batch 4:  Lost:     0.0060 Validation Accuracy:0.599000
# Epoch 84, CIFAR-10 Batch 5:  Lost:     0.0218 Validation Accuracy:0.595400
# Epoch 85, CIFAR-10 Batch 1:  Lost:     0.0141 Validation Accuracy:0.593200
# Epoch 85, CIFAR-10 Batch 2:  Lost:     0.0027 Validation Accuracy:0.598600
# Epoch 85, CIFAR-10 Batch 3:  Lost:     0.0076 Validation Accuracy:0.598000
# Epoch 85, CIFAR-10 Batch 4:  Lost:     0.0089 Validation Accuracy:0.598400
# Epoch 85, CIFAR-10 Batch 5:  Lost:     0.0082 Validation Accuracy:0.592600
# Epoch 86, CIFAR-10 Batch 1:  Lost:     0.0092 Validation Accuracy:0.592200
# Epoch 86, CIFAR-10 Batch 2:  Lost:     0.0091 Validation Accuracy:0.595800
# Epoch 86, CIFAR-10 Batch 3:  Lost:     0.0040 Validation Accuracy:0.600200
# Epoch 86, CIFAR-10 Batch 4:  Lost:     0.0043 Validation Accuracy:0.595800
# Epoch 86, CIFAR-10 Batch 5:  Lost:     0.0052 Validation Accuracy:0.604600
# Epoch 87, CIFAR-10 Batch 1:  Lost:     0.0121 Validation Accuracy:0.600200
# Epoch 87, CIFAR-10 Batch 2:  Lost:     0.0105 Validation Accuracy:0.592600
# Epoch 87, CIFAR-10 Batch 3:  Lost:     0.0093 Validation Accuracy:0.596600
# Epoch 87, CIFAR-10 Batch 4:  Lost:     0.0081 Validation Accuracy:0.590600
# Epoch 87, CIFAR-10 Batch 5:  Lost:     0.0088 Validation Accuracy:0.601200
# Epoch 88, CIFAR-10 Batch 1:  Lost:     0.0061 Validation Accuracy:0.588200
# Epoch 88, CIFAR-10 Batch 2:  Lost:     0.0010 Validation Accuracy:0.599600
# Epoch 88, CIFAR-10 Batch 3:  Lost:     0.0009 Validation Accuracy:0.609000
# Epoch 88, CIFAR-10 Batch 4:  Lost:     0.0119 Validation Accuracy:0.602200
# Epoch 88, CIFAR-10 Batch 5:  Lost:     0.0037 Validation Accuracy:0.603200
# Epoch 89, CIFAR-10 Batch 1:  Lost:     0.0084 Validation Accuracy:0.599600
# Epoch 89, CIFAR-10 Batch 2:  Lost:     0.0058 Validation Accuracy:0.590000
# Epoch 89, CIFAR-10 Batch 3:  Lost:     0.0037 Validation Accuracy:0.597600
# Epoch 89, CIFAR-10 Batch 4:  Lost:     0.0109 Validation Accuracy:0.605000
# Epoch 89, CIFAR-10 Batch 5:  Lost:     0.0041 Validation Accuracy:0.601000
# Epoch 90, CIFAR-10 Batch 1:  Lost:     0.0091 Validation Accuracy:0.600400
# Epoch 90, CIFAR-10 Batch 2:  Lost:     0.0061 Validation Accuracy:0.585000
# Epoch 90, CIFAR-10 Batch 3:  Lost:     0.0011 Validation Accuracy:0.604000
# Epoch 90, CIFAR-10 Batch 4:  Lost:     0.0121 Validation Accuracy:0.594800
# Epoch 90, CIFAR-10 Batch 5:  Lost:     0.0029 Validation Accuracy:0.611200
# Epoch 91, CIFAR-10 Batch 1:  Lost:     0.0118 Validation Accuracy:0.597200
# Epoch 91, CIFAR-10 Batch 2:  Lost:     0.0122 Validation Accuracy:0.603400
# Epoch 91, CIFAR-10 Batch 3:  Lost:     0.0015 Validation Accuracy:0.599400
# Epoch 91, CIFAR-10 Batch 4:  Lost:     0.0086 Validation Accuracy:0.607800
# Epoch 91, CIFAR-10 Batch 5:  Lost:     0.0025 Validation Accuracy:0.596800
# Epoch 92, CIFAR-10 Batch 1:  Lost:     0.0214 Validation Accuracy:0.604600
# Epoch 92, CIFAR-10 Batch 2:  Lost:     0.0058 Validation Accuracy:0.599200
# Epoch 92, CIFAR-10 Batch 3:  Lost:     0.0012 Validation Accuracy:0.602600
# Epoch 92, CIFAR-10 Batch 4:  Lost:     0.0043 Validation Accuracy:0.599000
# Epoch 92, CIFAR-10 Batch 5:  Lost:     0.0073 Validation Accuracy:0.596800
# Epoch 93, CIFAR-10 Batch 1:  Lost:     0.0061 Validation Accuracy:0.583800
# Epoch 93, CIFAR-10 Batch 2:  Lost:     0.0062 Validation Accuracy:0.584200
# Epoch 93, CIFAR-10 Batch 3:  Lost:     0.0013 Validation Accuracy:0.609200
# Epoch 93, CIFAR-10 Batch 4:  Lost:     0.0055 Validation Accuracy:0.592400
# Epoch 93, CIFAR-10 Batch 5:  Lost:     0.0114 Validation Accuracy:0.603200
# Epoch 94, CIFAR-10 Batch 1:  Lost:     0.0039 Validation Accuracy:0.595000
# Epoch 94, CIFAR-10 Batch 2:  Lost:     0.0033 Validation Accuracy:0.601400
# Epoch 94, CIFAR-10 Batch 3:  Lost:     0.0071 Validation Accuracy:0.593800
# Epoch 94, CIFAR-10 Batch 4:  Lost:     0.0066 Validation Accuracy:0.592200
# Epoch 94, CIFAR-10 Batch 5:  Lost:     0.0065 Validation Accuracy:0.605000
# Epoch 95, CIFAR-10 Batch 1:  Lost:     0.0055 Validation Accuracy:0.608400
# Epoch 95, CIFAR-10 Batch 2:  Lost:     0.0021 Validation Accuracy:0.607400
# Epoch 95, CIFAR-10 Batch 3:  Lost:     0.0076 Validation Accuracy:0.601800
# Epoch 95, CIFAR-10 Batch 4:  Lost:     0.0280 Validation Accuracy:0.599200
# Epoch 95, CIFAR-10 Batch 5:  Lost:     0.0082 Validation Accuracy:0.602000
# Epoch 96, CIFAR-10 Batch 1:  Lost:     0.0360 Validation Accuracy:0.590600
# Epoch 96, CIFAR-10 Batch 2:  Lost:     0.0069 Validation Accuracy:0.585000
# Epoch 96, CIFAR-10 Batch 3:  Lost:     0.0016 Validation Accuracy:0.601400
# Epoch 96, CIFAR-10 Batch 4:  Lost:     0.0130 Validation Accuracy:0.591000
# Epoch 96, CIFAR-10 Batch 5:  Lost:     0.0130 Validation Accuracy:0.601800
# Epoch 97, CIFAR-10 Batch 1:  Lost:     0.0042 Validation Accuracy:0.609000
# Epoch 97, CIFAR-10 Batch 2:  Lost:     0.0050 Validation Accuracy:0.600600
# Epoch 97, CIFAR-10 Batch 3:  Lost:     0.0020 Validation Accuracy:0.601200
# Epoch 97, CIFAR-10 Batch 4:  Lost:     0.0207 Validation Accuracy:0.585200
# Epoch 97, CIFAR-10 Batch 5:  Lost:     0.0063 Validation Accuracy:0.598200
# Epoch 98, CIFAR-10 Batch 1:  Lost:     0.0040 Validation Accuracy:0.599000
# Epoch 98, CIFAR-10 Batch 2:  Lost:     0.0037 Validation Accuracy:0.595600
# Epoch 98, CIFAR-10 Batch 3:  Lost:     0.0163 Validation Accuracy:0.606000
# Epoch 98, CIFAR-10 Batch 4:  Lost:     0.0127 Validation Accuracy:0.591600
# Epoch 98, CIFAR-10 Batch 5:  Lost:     0.0075 Validation Accuracy:0.593800
# Epoch 99, CIFAR-10 Batch 1:  Lost:     0.0087 Validation Accuracy:0.599400
# Epoch 99, CIFAR-10 Batch 2:  Lost:     0.0027 Validation Accuracy:0.603800
# Epoch 99, CIFAR-10 Batch 3:  Lost:     0.0056 Validation Accuracy:0.605600
# Epoch 99, CIFAR-10 Batch 4:  Lost:     0.0033 Validation Accuracy:0.595200
# Epoch 99, CIFAR-10 Batch 5:  Lost:     0.0086 Validation Accuracy:0.602400
# Epoch 100, CIFAR-10 Batch 1:  Lost:     0.0111 Validation Accuracy:0.606000
# Epoch 100, CIFAR-10 Batch 2:  Lost:     0.0012 Validation Accuracy:0.605600
# Epoch 100, CIFAR-10 Batch 3:  Lost:     0.0046 Validation Accuracy:0.608600
# Epoch 100, CIFAR-10 Batch 4:  Lost:     0.0140 Validation Accuracy:0.595600
# Epoch 100, CIFAR-10 Batch 5:  Lost:     0.0048 Validation Accuracy:0.593800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6003184713375797

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
